# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import os
import logging
import arviz as az

# %%
# Set up logging: messages will include timestamp, log level, and message content
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

PATH_MODEL = '/volumes/hyijie_psy/CPP_stage2_HDDM/mid_van_2019/model_fitted'
PATH_MODEL_FIt = '../results/ddm'
os.makedirs(PATH_MODEL_FIt, exist_ok=True)

MODEL_CONFIG = {
    'm2_ams': {
        'main_param': 'v_ams',
        'interactions': [
            'v_C(condition)[T.2.0]:ams',
            'v_C(condition)[T.3.0]:ams',
            'v_C(condition)[T.4.0]:ams'
        ]
    },
    'm2_pams': {
        'main_param': 'v_pams',
        'interactions': [
            'v_C(condition)[T.2.0]:pams',
            'v_C(condition)[T.3.0]:pams',
            'v_C(condition)[T.4.0]:pams'
        ]
    },
    'm2_slps': {
        'main_param': 'v_slps',
        'interactions': [
            'v_C(condition)[T.2.0]:slps',
            'v_C(condition)[T.3.0]:slps',
            'v_C(condition)[T.4.0]:slps'
        ]
    },
    'm2_ams_bin': {
        'main_param': 'v_ams_bin',
        'interactions': [
            'v_C(condition)[T.2.0]:ams_bin',
            'v_C(condition)[T.3.0]:ams_bin',
            'v_C(condition)[T.4.0]:ams_bin'
        ]
    },
    'm2_pams_bin': {
        'main_param': 'v_pam_bin',
        'interactions': [
            'v_C(condition)[T.2.0]:pam_bin',
            'v_C(condition)[T.3.0]:pam_bin',
            'v_C(condition)[T.4.0]:pam_bin'
        ]
    },
    'm2_slps_bin': {
        'main_param': 'v_slp_bin',
        'interactions': [
            'v_C(condition)[T.2.0]:slp_bin',
            'v_C(condition)[T.3.0]:slp_bin',
            'v_C(condition)[T.4.0]:slp_bin'
        ]
    }
}

# %%
# Extract and save posterior and Loo value

loo_results = []

for model_name, config in MODEL_CONFIG.items():

    main_param = config['main_param']
    interaction_names = config['interactions']
    
    path_model_infdata = os.path.join(PATH_MODEL, model_name + '.nc')
    assert os.path.exists(path_model_infdata), f" nc file not found: {model_name}"
    
    logger.info(f"Processing model: {model_name}")

    # Extract and save Loo for all models
    m_infdata = az.from_netcdf(path_model_infdata)
    
    loo = az.loo(m_infdata, pointwise=True)
    loo_dict = {
            "model": main_param,
            "loo": loo.elpd_loo,
            "p_loo": loo.p_loo
        }
    loo_results.append(loo_dict)

    # Save posterior data for all models
    posterior_dict = {}

    # Main effect
    if main_param in m_infdata.posterior:
        posterior_dict[main_param] = m_infdata.posterior[main_param].stack(sample=("chain", "draw")).values
    else:
        logger.error(f"Main parameter '{main_param}' not in {model_name}")
        continue
    # Interaction effect
    for inter in interaction_names:
        if inter in m_infdata.posterior:
            posterior_dict[inter] = m_infdata.posterior[inter].stack(sample=("chain", "draw")).values
        else:
            logger.warning(f"Interaction '{inter}' not found in model '{model_name}'")

    # Save data
    data_posterior = pd.DataFrame(posterior_dict)
    path_save_posterior = os.path.join(PATH_MODEL_FIt, f'{model_name}_posterior.csv')
    data_posterior.to_csv(path_save_posterior, index=False)

loo_df = pd.DataFrame(loo_results)
loo_df.to_csv(os.path.join(PATH_MODEL_FIt, "loo_comparison.csv"), index=False)
# Out:
# 2025-12-27 13:08:21,349 - INFO - Processing model: m2_ams
# 2025-12-27 13:08:26,031 - INFO - Processing model: m2_pams
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 16
#      13 logger.info(f"Processing model: {model_name}")
#      15 # Extract and save Loo for all models
# ---> 16 m_infdata = az.from_netcdf(path_model_infdata)
#      18 #loo = az.loo(m_infdata, pointwise=True)
#      19 #loo_dict = {
#      20 #        "model": main_param,
#    (...)     25
#      26 # Save posterior data for all models
#      27 posterior_dict = {}
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/arviz/data/io_netcdf.py:36, in from_netcdf(filename, engine, group_kwargs, regex)
#      34 if group_kwargs is None:
#      35     group_kwargs = {}
# ---> 36 return InferenceData.from_netcdf(
#      37     filename, engine=engine, group_kwargs=group_kwargs, regex=regex
#      38 )
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/arviz/data/inference_data.py:433, in InferenceData.from_netcdf(filename, engine, group_kwargs, regex, base_group)
#     431             group_kws = kws
#     432 group_kws.setdefault("engine", engine)
# --> 433 data = xr.open_dataset(filename, group=f"{base_group}/{group}", **group_kws)
#     434 if rcParams["data.load"] == "eager":
#     435     with data:
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/backends/api.py:606, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     594 decoders = _resolve_decoders_kwargs(
#     595     decode_cf,
#     596     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    602     decode_coords=decode_coords,
#     603 )
#     605 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 606 backend_ds = backend.open_dataset(
#     607     filename_or_obj,
#     608     drop_variables=drop_variables,
#     609     **decoders,
#     610     **kwargs,
#     611 )
#     612 ds = _dataset_from_backend_dataset(
#     613     backend_ds,
#     614     filename_or_obj,
#    (...)    625     **kwargs,
#     626 )
#     627 return ds
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/backends/h5netcdf_.py:555, in H5netcdfBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     540 store = H5NetCDFStore.open(
#     541     filename_or_obj,
#     542     format=format,
#    (...)    550     storage_options=storage_options,
#     551 )
#     553 store_entrypoint = StoreBackendEntrypoint()
# --> 555 ds = store_entrypoint.open_dataset(
#     556     store,
#     557     mask_and_scale=mask_and_scale,
#     558     decode_times=decode_times,
#     559     concat_characters=concat_characters,
#     560     decode_coords=decode_coords,
#     561     drop_variables=drop_variables,
#     562     use_cftime=use_cftime,
#     563     decode_timedelta=decode_timedelta,
#     564 )
#     566 # only warn if phony_dims exist in file
#     567 # remove together with the above check
#     568 # after some versions
#     569 if store.ds._root._phony_dim_count > 0 and emit_phony_dims_warning:
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/backends/store.py:45, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, set_indexes, use_cftime, decode_timedelta)
#      42 vars, attrs = filename_or_obj.load()
#      43 encoding = filename_or_obj.get_encoding()
# ---> 45 vars, attrs, coord_names = conventions.decode_cf_variables(
#      46     vars,
#      47     attrs,
#      48     mask_and_scale=mask_and_scale,
#      49     decode_times=decode_times,
#      50     concat_characters=concat_characters,
#      51     decode_coords=decode_coords,
#      52     drop_variables=drop_variables,
#      53     use_cftime=use_cftime,
#      54     decode_timedelta=decode_timedelta,
#      55 )
#      57 # split data and coordinate variables (promote dimension coordinates)
#      58 data_vars = {}
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/conventions.py:412, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     405 stack_char_dim = (
#     406     _item_or_default(concat_characters, k, True)
#     407     and v.dtype == "S1"
#     408     and v.ndim > 0
#     409     and stackable(v.dims[-1])
#     410 )
#     411 try:
# --> 412     new_vars[k] = decode_cf_variable(
#     413         k,
#     414         v,
#     415         concat_characters=_item_or_default(concat_characters, k, True),
#     416         mask_and_scale=_item_or_default(mask_and_scale, k, True),
#     417         decode_times=cast(
#     418             bool | CFDatetimeCoder, _item_or_default(decode_times, k, True)
#     419         ),
#     420         stack_char_dim=stack_char_dim,
#     421         use_cftime=_item_or_default(use_cftime, k, None),
#     422         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     423     )
#     424 except Exception as e:
#     425     e.add_note(f"Raised while decoding variable {k!r} with value {v!r}")
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/conventions.py:189, in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     186     var = strings.EncodedStringCoder().decode(var)
#     188 if original_dtype.kind == "O":
# --> 189     var = variables.ObjectVLenStringCoder().decode(var)
#     190     original_dtype = var.dtype
#     192 if original_dtype.kind == "T":
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/coding/variables.py:664, in ObjectVLenStringCoder.decode(self, variable, name)
#     662 def decode(self, variable: Variable, name: T_Name = None) -> Variable:
#     663     if variable.dtype.kind == "O" and variable.encoding.get("dtype", False) is str:
# --> 664         variable = variable.astype(variable.encoding["dtype"])
#     665         return variable
#     666     else:
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/core/variable.py:540, in Variable.astype(self, dtype, order, casting, subok, copy, keep_attrs)
#     537 kwargs = dict(order=order, casting=casting, subok=subok, copy=copy)
#     538 kwargs = {k: v for k, v in kwargs.items() if v is not None}
# --> 540 return apply_ufunc(
#     541     duck_array_ops.astype,
#     542     self,
#     543     dtype,
#     544     kwargs=kwargs,
#     545     keep_attrs=keep_attrs,
#     546     dask="allowed",
#     547 )
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:1277, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1275 # feed Variables directly through apply_variable_ufunc
#    1276 elif any(isinstance(a, Variable) for a in args):
# -> 1277     return variables_vfunc(*args)
#    1278 else:
#    1279     # feed anything else through apply_array_ufunc
#    1280     return apply_array_ufunc(func, *args, dask=dask)
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:818, in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     813 elif vectorize:
#     814     func = _vectorize(
#     815         func, signature, output_dtypes=output_dtypes, exclude_dims=exclude_dims
#     816     )
# --> 818 result_data = func(*input_data)
#     820 if signature.num_outputs == 1:
#     821     result_data = (result_data,)
#
# File /opt/miniconda3/envs/env4eeg/lib/python3.13/site-packages/xarray/core/duck_array_ops.py:258, in astype(data, dtype, xp, **kwargs)
#     254     xp = get_array_namespace(data)
#     256 if xp == np:
#     257     # numpy currently doesn't have a astype:
# --> 258     return data.astype(dtype, **kwargs)
#     259 return xp.astype(data, dtype, **kwargs)
#
# KeyboardInterrupt:

# %%
path_model_infdata = os.path.join(PATH_MODEL, 'm2_slps.nc')
assert os.path.exists(path_model_infdata), f" nc file not found: {model_name}"

# Extract and save Loo for all models
m_infdata = az.from_netcdf(path_model_infdata)

# %%
az.summary(m_infdata)
# Out:
#                                      mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# a                                   1.277  0.040   1.203    1.354      0.000
# a_std                               0.177  0.033   0.120    0.239      0.000
# a_subj.14                           1.190  0.060   1.083    1.302      0.001
# a_subj.15                           1.316  0.050   1.224    1.411      0.000
# a_subj.16                           1.473  0.076   1.338    1.623      0.001
# ...                                   ...    ...     ...      ...        ...
# v_C(condition)[T.4.0]:slps_subj.32  0.259  0.216  -0.102    0.687      0.011
# v_C(condition)[T.4.0]:slps_subj.33  0.142  0.190  -0.208    0.521      0.010
# v_C(condition)[T.4.0]:slps_subj.34 -0.008  0.187  -0.369    0.345      0.008
# v_C(condition)[T.4.0]:slps_subj.35 -0.040  0.209  -0.458    0.335      0.008
# v_C(condition)[T.4.0]:slps_subj.36 -0.020  0.172  -0.345    0.305      0.008
#
#                                     mcse_sd  ess_bulk  ess_tail  r_hat
# a                                     0.000   11419.0   12279.0   1.00
# a_std                                 0.000    8265.0   10539.0   1.00
# a_subj.14                             0.000    3823.0    9663.0   1.00
# a_subj.15                             0.000   11432.0   13428.0   1.00
# a_subj.16                             0.001    2950.0    3679.0   1.00
# ...                                     ...       ...       ...    ...
# v_C(condition)[T.4.0]:slps_subj.32    0.002     331.0    1542.0   1.02
# v_C(condition)[T.4.0]:slps_subj.33    0.003     392.0    2840.0   1.01
# v_C(condition)[T.4.0]:slps_subj.34    0.002     534.0    3747.0   1.01
# v_C(condition)[T.4.0]:slps_subj.35    0.003     711.0    4098.0   1.01
# v_C(condition)[T.4.0]:slps_subj.36    0.002     503.0    3622.0   1.01
#
# [275 rows x 9 columns]

# %%
m_infdata.lik
# Out:
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> prior
# 	> observed_data
